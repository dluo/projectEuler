# %%
import pprint

# %%
s = """08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08
49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00
81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65
52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91
22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80
24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50
32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70
67 26 20 68 02 62 12 20 95 63 94 39 63 08 40 91 66 49 94 21
24 55 58 05 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72
21 36 23 09 75 00 76 44 20 45 35 14 00 61 33 97 34 31 33 95
78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92
16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57
86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58
19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40
04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66
88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69
04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36
20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16
20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54
01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48"""

dataPoints = s.split()
print(data)

count = 0

twoDArr = []
curRow = []
for data in dataPoints:
    curRow.append(int(data))
    
    if((count+1) % 20 == 0):
        twoDArr.append(curRow)
        curRow = []
    
    count+=1;

pp = pprint.PrettyPrinter()
print(twoDArr)
# Out:
# 48
# ...

# %%
twoDArr[0][0]

def prod(nums):
    prod = 1
    for num in nums:
        prod *= num
    return prod
    
def largestProd(grid):
    width = len(grid)
    height = len(grid[0])
    #print(width)
    if (width <= 4 and height <=4):
        
        maxProd = 1
        
        if width == 4:
            for row in grid:
                curProd = prod(row)
                if curProd > maxProd:
                    maxProd = curProd
        
        if height == 4:
            for i in range(0, width):
                curProd = prod([grid[0][i], grid[1][i], grid[2][i], grid[3][i]])
                if curProd > maxProd:
                    maxProd = curProd
        
        if width == 4 and height == 4:
            #diagonal
            nums = []
            for i in range(0, 4):
                nums.append(grid[i][i])
            
            curProd = prod(nums)
            if curProd > maxProd:
                maxProd = curProd
            
            nums = []
            for i in range(0, 4):
                nums.append(grid[3-i][i])
            
            curProd = prod(nums)
            if curProd > maxProd:
                maxProd = curProd
        
        return maxProd
    
    else:
        size = len(grid)
        
        maxProd = 0
        curProd = 0
        quads = []
        
        topLeft = [twoDArr[i][0:size/2] for i in range(0, size/2)]
        topRight = [twoDArr[i][size/2:] for i in range(0, size/2)]
        botLeft = [twoDArr[i][0:size/2] for i in range(size/2, size)]
        botRight = [twoDArr[i][size/2:] for i in range(size/2, size)]
        
        quads.append(topLeft)
        quads.append(topRight)
        quads.append(botLeft)
        quads.append(botRight)
        
        for quad in quads:
            curProd = largestProd(topLeft)
            if curProd > maxProd:
                maxProd = curProd
        
        for i in range(max(size/2 - 3, 0), min(size/2+3), size):
            
        halfway = size/2
        
        return maxProd
        
slice = [twoDArr[i][0:16] for i in range(0, 16)]
print(largestProd(twoDArr))
# Out:
#   File "<ipython-input-52-1b9da88f0a3a>", line 73
#     halfway = size/2
#           ^
# IndentationError: expected an indented block

# %%
def prod(nums):
    prod = 1
    for num in nums:
        prod *= num
    return prod

def largestProdIter(grid):
    size = len(grid)
    print(size)
    maxProd = 0
    maxNums = []
    
    curProd = 0 
    for row in grid:
        for i in range(0, size - 3):
            #print(row[i:i+4])
            curProd = prod(row[i:i+4])
            if curProd > maxProd:
                maxProd = curProd
                maxNums = row[i:i+4]
    
    nums = []
    for col in range(0, 20):
        for i in range(0, size - 3):
            for num in range(0, 4):
                nums.append(grid[i+num][col])
                
            curProd = prod(nums)
            if curProd > maxProd:
                maxProd = curProd
                maxNums = nums
            nums = []
    
    for row in range(0, size-3):
        for col in range(0, size-3):
            for num in range(0, 4):
                nums.append(grid[row+num][col+num])
            print(nums)
            curProd = prod(nums)
            if curProd > maxProd:
                maxProd = curProd
                maxNums = nums
            nums = []
    
    for row in range(0, size-3):
        for col in range(0, size-3):
            for num in range(0, 4):
                nums.append(grid[row+(3-num)][col+num])
            #print(nums)
            
            curProd = prod(nums)
            if curProd > maxProd:
                maxProd = curProd
                maxNums = nums
            nums = []
                
                
    print(maxProd)
    print(maxNums)
    return maxProd

print(largestProdIter(twoDArr))
# Out:
# 20
# [8, 49, 31, 23]
# [2, 99, 73, 4]
# [22, 40, 55, 60]
# [97, 17, 79, 11]
# [38, 81, 14, 42]
# [15, 18, 29, 69]
# [0, 57, 93, 24]
# [40, 60, 71, 68]
# [0, 87, 40, 56]
# [75, 17, 67, 1]
# [4, 40, 53, 32]
# [5, 98, 88, 56]
# [7, 43, 30, 71]
# [78, 69, 3, 37]
# [52, 48, 49, 2]
# [12, 4, 13, 36]
# [50, 56, 36, 91]
# [49, 49, 95, 71]
# [49, 31, 23, 51]
# [99, 73, 4, 67]
# [40, 55, 60, 63]
# [17, 79, 11, 89]
# [81, 14, 42, 41]
# [18, 29, 69, 92]
# [57, 93, 24, 36]
# [60, 71, 68, 54]
# [87, 40, 56, 22]
# [17, 67, 1, 40]
# [40, 53, 32, 40]
# [98, 88, 56, 28]
# [43, 30, 71, 66]
# [69, 3, 37, 33]
# [48, 49, 2, 13]
# [4, 13, 36, 80]
# [81, 70, 16, 60]
# [49, 95, 71, 99]
# [31, 23, 51, 3]
# [73, 4, 67, 45]
# [55, 60, 63, 2]
# [79, 11, 89, 44]
# [14, 42, 41, 75]
# [29, 69, 92, 33]
# [93, 24, 36, 53]
# [71, 68, 54, 78]
# [40, 56, 22, 36]
# [67, 1, 40, 84]
# [53, 32, 40, 20]
# [88, 56, 28, 35]
# [30, 71, 66, 17]
# [3, 37, 33, 12]
# [49, 2, 13, 50]
# [52, 31, 32, 28]
# [70, 16, 60, 64]
# ...
